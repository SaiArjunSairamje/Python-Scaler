# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiArjunSairamje/Python_Libraries/blob/main/08.%20Pandas_4%20(Dataset%3A%20Pharma_Experiment_Analysis)%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the Libraries and Dataset "Pharma Experiment Analysis"**
# ***

# %%
# !gdown 173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 7.91MB/s]

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Pfizer_1.csv")

# %%
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %% [markdown]
# # **What we will learn ???**
# ***
#
# > **(1) Convert wide-format to long-format `(i.e. Unpivot Columns to Rows)`**
#
# > **(2) How to handle missing values `(i.e. the NaN values)`**

# %% [markdown]
# # **(1)  Convert wide-format to long-format**
# ***
# **How to convert wide-format data into long-format date (i.e. transpose column to row) ???**
#
# The **pd.melt()** function in **pandas** is used to transform a DataFrame from a **wide format** to a **long format**. It **unpivots the DataFrame**, making it easier to analyze or visualize the data.
#
# Here's the basic syntax of the **pd.melt()** function:
#
# > **`pd.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', ...)`**
#
# **Parameters:**
#
# * **frame**: The DataFrame to be melted.
# * **id_vars**: Columns to use as identifier variables (remains as columns in the result).
# * **value_vars**: Columns to unpivot. If not specified, all columns not set as **id_vars** will be unpivoted.
# * **var_name**: Name to use for the variable column. By default, it is set to **'variable'**.
# * **value_name**: Name to use for the value column. By default, it is set to **'value'**.
# * Additional parameters for handling data types, sorting, etc.
#
# The pd.melt() function is helpful when you have a DataFrame with multiple columns, and you want to transform it into a long format for further analysis or visualization.

# %%
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
#id_vars - it's the column's that you don't want to change...

pd.melt(data, id_vars = ["Date", "Parameter", "Drug_Name"])
# Out:
#            Date    Parameter                Drug_Name  variable  value
# 0    15-10-2020  Temperature  diltiazem hydrochloride   1:30:00   23.0
# 1    15-10-2020     Pressure  diltiazem hydrochloride   1:30:00   12.0
# 2    15-10-2020  Temperature      docetaxel injection   1:30:00    NaN
# 3    15-10-2020     Pressure      docetaxel injection   1:30:00    NaN
# 4    15-10-2020  Temperature   ketamine hydrochloride   1:30:00   24.0
# ..          ...          ...                      ...       ...    ...
# 211  17-10-2020     Pressure  diltiazem hydrochloride  12:30:00   14.0
# 212  17-10-2020  Temperature      docetaxel injection  12:30:00   23.0
# 213  17-10-2020     Pressure      docetaxel injection  12:30:00   28.0
# 214  17-10-2020  Temperature   ketamine hydrochloride  12:30:00   24.0
# 215  17-10-2020     Pressure   ketamine hydrochloride  12:30:00   15.0
#
# [216 rows x 5 columns]

# %% [markdown]
# ### **How to change the "variable" & "value" column names as per my choice ???**

# %%
pd.melt(data,
        id_vars = ["Date", "Parameter", "Drug_Name"],    #id_vars - it's the column's that you don't want to change
        var_name = "time",     #var_name - it will change the "variable" column name to "time"
        value_name = "reading"     #value_name - it will change the "value" column name to "value_name"
        )
# Out:
#            Date    Parameter                Drug_Name      time  reading
# 0    15-10-2020  Temperature  diltiazem hydrochloride   1:30:00     23.0
# 1    15-10-2020     Pressure  diltiazem hydrochloride   1:30:00     12.0
# 2    15-10-2020  Temperature      docetaxel injection   1:30:00      NaN
# 3    15-10-2020     Pressure      docetaxel injection   1:30:00      NaN
# 4    15-10-2020  Temperature   ketamine hydrochloride   1:30:00     24.0
# ..          ...          ...                      ...       ...      ...
# 211  17-10-2020     Pressure  diltiazem hydrochloride  12:30:00     14.0
# 212  17-10-2020  Temperature      docetaxel injection  12:30:00     23.0
# 213  17-10-2020     Pressure      docetaxel injection  12:30:00     28.0
# 214  17-10-2020  Temperature   ketamine hydrochloride  12:30:00     24.0
# 215  17-10-2020     Pressure   ketamine hydrochloride  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
# storing the data into a new variable so that we can retain the original data as it is...

data_melt = pd.melt(data,
        id_vars = ["Date", "Parameter", "Drug_Name"],
        var_name = "time",
        value_name = "reading"
        )

# %%
data_melt.head()
# Out:
#          Date    Parameter                Drug_Name     time  reading
# 0  15-10-2020  Temperature  diltiazem hydrochloride  1:30:00     23.0
# 1  15-10-2020     Pressure  diltiazem hydrochloride  1:30:00     12.0
# 2  15-10-2020  Temperature      docetaxel injection  1:30:00      NaN
# 3  15-10-2020     Pressure      docetaxel injection  1:30:00      NaN
# 4  15-10-2020  Temperature   ketamine hydrochloride  1:30:00     24.0

# %% [markdown]
# ### **How to convert back from long-format data into white-format date (i.e. transpose row to column) ???**
#
# The **pivot()** function in pandas is used to reshape a DataFrame from **long format** to **wide format**. It is particularly useful when you want to convert data that has been **melted** or **unpivoted** back to its original structure.
#
# Here's the basic syntax of the **pivot()** function:
#
# > **`DataFrame.pivot(index=None, columns=None, values=None)`**
#
# **Parameters:**
#
# * **index**: The column to be used as the index in the pivoted DataFrame. It can be a column label, column name, or a list of column labels/names. If not specified, the index will be auto-generated.
# * **columns**: The column to be used as the columns in the pivoted DataFrame. It can be a column label, column name, or a list of column labels/names.
# values: The column to be used as the values in the pivoted DataFrame. It specifies the values to be populated in the new columns based on the index and * **columns**. It can be a column label, column name, or a list of column labels/names.
#
# The **pivot()** function is a convenient way to reshape data from long to wide format in pandas.

# %%
#long ==> wide

# %%
data_tidy = data_melt.pivot(index = ["Date" , "Drug_Name" , "Parameter"],  #index - it's the column's that you don't want to change
                columns = "time",     #columns - the column that you want to be changed as header
                values = "reading"    #values -
                )

# %%
data_tidy
# Out:
# time                                            10:30:00  11:30:00  12:30:00  \
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure         18.0      19.0      20.0
#                                    Temperature      20.0      20.0      21.0
#            docetaxel injection     Pressure         26.0      29.0      28.0
#                                    Temperature      23.0      25.0      25.0
#            ketamine hydrochloride  Pressure          9.0       9.0      11.0
#                                    Temperature      22.0      21.0      20.0
# 16-10-2020 diltiazem hydrochloride Pressure         24.0       NaN      27.0
#                                    Temperature      40.0       NaN      42.0
#            docetaxel injection     Pressure         28.0      29.0      30.0
#                                    Temperature      56.0      57.0      58.0
#            ketamine hydrochloride  Pressure         16.0      17.0      18.0
# ...

# %%
data_tidy = data_tidy.reset_index() #adjusted the "time" subheading as shown above

# %%
data_tidy.head()  #NOTE: the "time" column is nothing but the index column
# Out:
# time        Date                Drug_Name    Parameter  10:30:00  11:30:00  \
# 0     15-10-2020  diltiazem hydrochloride     Pressure      18.0      19.0
# 1     15-10-2020  diltiazem hydrochloride  Temperature      20.0      20.0
# 2     15-10-2020      docetaxel injection     Pressure      26.0      29.0
# 3     15-10-2020      docetaxel injection  Temperature      23.0      25.0
# 4     15-10-2020   ketamine hydrochloride     Pressure       9.0       9.0
#
# time  12:30:00  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  \
# 0         20.0     12.0     13.0      NaN     11.0     13.0     14.0     16.0
# 1         21.0     23.0     22.0      NaN     21.0     21.0     22.0     23.0
# 2         28.0      NaN     22.0     22.0      NaN     22.0     23.0      NaN
# 3         25.0      NaN     17.0     18.0      NaN     17.0     18.0      NaN
# 4         11.0      8.0      NaN      NaN      7.0      NaN      9.0     10.0
#
# time  8:30:00  9:30:00
# ...

# %%
data_tidy.info()  #as you can see, you won't see the "time" index column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   10:30:00   18 non-null     float64
#  4   11:30:00   16 non-null     float64
#  5   12:30:00   18 non-null     float64
#  6   1:30:00    16 non-null     float64
#  7   2:30:00    16 non-null     float64
#  8   3:30:00    12 non-null     float64
#  9   4:30:00    14 non-null     float64
#  10  5:30:00    16 non-null     float64
#  11  6:30:00    18 non-null     float64
#  12  7:30:00    16 non-null     float64
#  13  8:30:00    14 non-null     float64
#  14  9:30:00    16 non-null     float64
# dtypes: float64(12), object(3)
# memory usage: 2.2+ KB

# %%
#NOTE: Just trying to see if we can remove the "time" index column

data_tidy.columns.name = "None"

# %%
data_tidy.head()
# Out:
# None        Date                Drug_Name    Parameter  10:30:00  11:30:00  \
# 0     15-10-2020  diltiazem hydrochloride     Pressure      18.0      19.0
# 1     15-10-2020  diltiazem hydrochloride  Temperature      20.0      20.0
# 2     15-10-2020      docetaxel injection     Pressure      26.0      29.0
# 3     15-10-2020      docetaxel injection  Temperature      23.0      25.0
# 4     15-10-2020   ketamine hydrochloride     Pressure       9.0       9.0
#
# None  12:30:00  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  \
# 0         20.0     12.0     13.0      NaN     11.0     13.0     14.0     16.0
# 1         21.0     23.0     22.0      NaN     21.0     21.0     22.0     23.0
# 2         28.0      NaN     22.0     22.0      NaN     22.0     23.0      NaN
# 3         25.0      NaN     17.0     18.0      NaN     17.0     18.0      NaN
# 4         11.0      8.0      NaN      NaN      7.0      NaN      9.0     10.0
#
# None  8:30:00  9:30:00
# ...

# %% [markdown]
# ### **For a given date, for a given time, and for a perticular drug_name, I want to the have 2 values as it's column namely temperature and pressure.**
#
# **Example of the expected o/p table**
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
data_melt.head()
# Out:
#          Date    Parameter                Drug_Name     time  reading
# 0  15-10-2020  Temperature  diltiazem hydrochloride  1:30:00     23.0
# 1  15-10-2020     Pressure  diltiazem hydrochloride  1:30:00     12.0
# 2  15-10-2020  Temperature      docetaxel injection  1:30:00      NaN
# 3  15-10-2020     Pressure      docetaxel injection  1:30:00      NaN
# 4  15-10-2020  Temperature   ketamine hydrochloride  1:30:00     24.0

# %%
data_tidy = data_melt.pivot(
    index = ["Date", "time", "Drug_Name"],
    columns = "Parameter",
    values = "reading"
)

# %%
data_tidy.head(15)  #we're getting o/p where at a given time, what drug_name and its pressure and temperature value are...
# Out:
# Parameter                                    Pressure  Temperature
# Date       time     Drug_Name
# 15-10-2020 10:30:00 diltiazem hydrochloride      18.0         20.0
#                     docetaxel injection          26.0         23.0
#                     ketamine hydrochloride        9.0         22.0
#            11:30:00 diltiazem hydrochloride      19.0         20.0
#                     docetaxel injection          29.0         25.0
#                     ketamine hydrochloride        9.0         21.0
#            12:30:00 diltiazem hydrochloride      20.0         21.0
#                     docetaxel injection          28.0         25.0
#                     ketamine hydrochloride       11.0         20.0
#            1:30:00  diltiazem hydrochloride      12.0         23.0
#                     docetaxel injection           NaN          NaN
#                     ketamine hydrochloride        8.0         24.0
#            2:30:00  diltiazem hydrochloride      13.0         22.0
# ...

# %%
data_tidy.reset_index()  #adjusting the "Parameter" subheading as the index column
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 23.0
# 2                 22.0
# 3                 20.0
# 4                 25.0
# ...

# %% [markdown]
# # **List Comprehension**
# ***
#
# **List comprehension** is a concise and efficient way to create new lists by performing operations on existing lists or other iterables. It allows you to combine loops, conditions, and expressions into a single line of code.
#
# Here's the general syntax of a **list comprehension**:
#
# > **`new_list = [expression for item in iterable if condition]`**
#
# **Components of list comprehension:**
#
# * **expression**: The expression that defines how each item in the iterable is transformed or manipulated to create a new element in the new list.
# * **item**: The variable that represents each item in the iterable.
# * **iterable**: The existing list, tuple, string, or any other iterable from which you want to create a new list.
# * **condition** (optional): An optional condition that filters the items from the iterable based on a specified condition. Only the items that satisfy the condition are included in the new list.

# %% [markdown]
# ### **Given a list of elements, give me the cube of these elements**
#
# > **`Approach (1):`** Normal **Python code**
#
# > **`Approach (2):`** Using **"List compreshension"**

# %%
a = [4, 7, 3]
# b = [16, 49, 9]

# %%
# Approach (1): Normal Python code Approach

a = [4, 7, 3]

b = []

for elem in a:
  b.append(elem**2)

print(b)
# Out:
# [16, 49, 9]

# %%
# Approach (2): Using List Comprehension Approach

b = [elem**2 for elem in a]

# %%
print(b)
# Out:
# [16, 49, 9]

# %% [markdown]
# **`Another example:  `**
# **Given a list, provide a new list which stores twice the value of the previous list elements.**

# %%
a = [4, 7, 3]

# %%
b = [elem*2 for elem in a]

# %%
print(b)
# Out:
# [8, 14, 6]

# %% [markdown]
# ### **"If" statement using "List Comprehension"**
#
# **Given a new list, create a new list where you strore every element except 5 in the same sequence**

# %%
a = [4, 7, 5, 9, 3]
#create a new list where you strore every element except 5 in the same sequence
# b = [4, 7, 9, 3]

# %%
b = [elem for elem in a if elem != 5]

# %%
print(b)
# Out:
# [4, 7, 9, 3]

# %% [markdown]
# ### **"If-else" statement using "List Comprehension"**
#
# **Given a list, create a new list which stores the number as it is if it is even and stores the double of it, if it is odd**
#
# > **`Approach (1):`** Normal **Python code**
#
# > **`Approach (2):`** Using **"If-else"** stetement in **"List compreshension"**

# %%
#if-else

# %%
#Given a list, create a new list which stores the number as it is if it is even and stores the double of it, if it is odd

a = [4, 7, 5, 8, 9]
# b = [4, 14, 10, 8, 18]

# %%
# Approach (1): Normal Python code

a = [4, 7, 5, 8, 9]

b = []

for elem in a:
  if elem%2 == 0:
    b.append(elem)
  else:
    b.append(2*elem)

print(b)
# Out:
# [4, 14, 10, 8, 18]

# %%
# Approach (2): Using "If-else" stetement in "List compreshension"

b = [elem if elem%2 == 0 else elem*2 for elem in a]

# %%
print(b)
# Out:
# [4, 14, 10, 8, 18]

# %% [markdown]
# # **Continue with next lecture**
# ***

# %% [markdown]
# As per our data, for a particular **drug_name**, for a particular **date**, there are **multiple timeframes** that has **temperature** and **pressure** data.
#
#
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ### **For a particular drug_name and particular date, give me the average temperature ???**
#
# **Expected o/p**
#
# ![Capture.PNG](data:image/png;base64,...)
#
# So far we had been using the **"pivot()"** function, but we will now use **"pivot_table()"** for **aggregating** the function.
#
# The **pivot_table()** function in **Pandas** is used to create a spreadsheet-style pivot table based on a DataFrame object. It allows you to summarize and aggregate data in a customizable way. Compared to the **pivot()** function, **pivot_table()** provides additional flexibility and functionality for aggregating data.
#
# Here's the general syntax of the **pivot_table()** function:
#
# > `**pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True)**`
#
# Let's go through the parameters commonly used with **pivot_table()**:
#
# * **data**: The DataFrame object containing the data.
# * **values**: (Optional) The column(s) to aggregate. By default, it considers all numeric columns.
# * **index**: (Optional) The column(s) to use as index in the resulting pivot table.
# * **columns**: (Optional) The column(s) to use as columns in the resulting pivot table.
# * **aggfunc**: (Optional) The aggregation function to apply to the values. It can be a built-in aggregator like 'sum', 'mean', 'count', etc., or a custom function.
# * **fill_value**: (Optional) The value to replace missing values with.
# * **margins**: (Optional) If True, it adds row and column totals to the pivot table.
# * **dropna**: (Optional) If True, it excludes columns that have all NaN values.

# %%
data_tidy.head(20)
# Out:
# Parameter                                    Pressure  Temperature
# Date       time     Drug_Name
# 15-10-2020 10:30:00 diltiazem hydrochloride      18.0         20.0
#                     docetaxel injection          26.0         23.0
#                     ketamine hydrochloride        9.0         22.0
#            11:30:00 diltiazem hydrochloride      19.0         20.0
#                     docetaxel injection          29.0         25.0
#                     ketamine hydrochloride        9.0         21.0
#            12:30:00 diltiazem hydrochloride      20.0         21.0
#                     docetaxel injection          28.0         25.0
#                     ketamine hydrochloride       11.0         20.0
#            1:30:00  diltiazem hydrochloride      12.0         23.0
#                     docetaxel injection           NaN          NaN
#                     ketamine hydrochloride        8.0         24.0
#            2:30:00  diltiazem hydrochloride      13.0         22.0
# ...

# %%
data_tidy.reset_index()
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 23.0
# 2                 22.0
# 3                 20.0
# 4                 25.0
# ...

# %%
data_tidy.head(20)
# Out:
# Parameter                                    Pressure  Temperature
# Date       time     Drug_Name
# 15-10-2020 10:30:00 diltiazem hydrochloride      18.0         20.0
#                     docetaxel injection          26.0         23.0
#                     ketamine hydrochloride        9.0         22.0
#            11:30:00 diltiazem hydrochloride      19.0         20.0
#                     docetaxel injection          29.0         25.0
#                     ketamine hydrochloride        9.0         21.0
#            12:30:00 diltiazem hydrochloride      20.0         21.0
#                     docetaxel injection          28.0         25.0
#                     ketamine hydrochloride       11.0         20.0
#            1:30:00  diltiazem hydrochloride      12.0         23.0
#                     docetaxel injection           NaN          NaN
#                     ketamine hydrochloride        8.0         24.0
#            2:30:00  diltiazem hydrochloride      13.0         22.0
# ...

# %%
data_tidy = data_tidy.reset_index()

# %%
data_tidy.pivot( index = ["Drug_Name"], columns = "Date", values = "Temperature")   #this will throw error message
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-6281b3571732> in <cell line: 1>()
# ----> 1 data_tidy.pivot( index = ["Drug_Name"], columns = "Date", values = "Temperature")   #this will throw error message
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    8565         from pandas.core.reshape.pivot import pivot
#    8566
# -> 8567         return pivot(self, index=index, columns=columns, values=values)
#    8568
#    8569     _shared_docs[
#
# ...

# %%
pd.pivot_table(data_tidy,
               index = "Drug_Name",
               columns = "Date",
               values = "Temperature",
               aggfunc = np.mean)
# Out:
# Date                     15-10-2020  16-10-2020  17-10-2020
# Drug_Name
# diltiazem hydrochloride   21.454545   37.454545   15.636364
# docetaxel injection       20.750000   51.454545   17.500000
# ketamine hydrochloride    23.555556   11.500000   18.500000

# %% [markdown]
# ### **Difference b/w "pivot()" and "pivot_table()" ???**
#
# The **pivot()** and **pivot_table()** functions in Pandas are both used to **reshape** and **restructure data.** However, there are some **differences** between them:
#
# **1. Aggregation:** The main difference between **pivot()** and **pivot_table()** is that **pivot()** performs a simple **reshaping** of the data, while **pivot_table()** allows for **aggregating** the data during the **reshaping** process. With **pivot()**, you can only rearrange the data based on the specified index and column values. On the other hand, **pivot_table()** allows you to apply aggregation functions to the values in the resulting table.
#
# **2. Handling Duplicate Values:** When using **pivot()**, if there are multiple values for a given combination of index and column, an error will be raised. In contrast, **pivot_table()** can handle duplicate values by applying an aggregation function (e.g., sum, mean, count) to consolidate them.
#
# **3. Multiple Aggregations: pivot_table()** allows you to specify multiple aggregation functions for the same data column, which is not possible with **pivot()**. You can pass a list of aggregation functions to the aggfunc parameter of **pivot_table()**.
#
# **4. Missing Values: pivot()** does not handle missing values explicitly. If there are missing values in the original DataFrame, they will be filled with **NaN** in the resulting pivot table. **pivot_table()** provides the fill_value parameter, which allows you to specify a value to replace missing values during the aggregation.
#
# In summary, **pivot()** is useful for **reshaping data without any aggregation**, while **pivot_table()** is more versatile and allows for **aggregating data during the reshaping process**. If you need to summarize or aggregate your data based on specific criteria, **pivot_table()** is the preferred choice.

# %% [markdown]
# ### **What if I want to have both the average temperature as well as the average pressure for each drug at particular time ???**
#
# That is, we want to have 2 readings/metrics to measure the o/p...
#
# **Expected o/p**
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
pd.pivot_table(data_tidy,
               index = "Drug_Name",
               columns = "Date",
               values = ["Temperature", "Pressure"],
               aggfunc = np.mean)
# Out:
# Parameter                 Pressure                       Temperature  \
# Date                    15-10-2020 16-10-2020 17-10-2020  15-10-2020
# Drug_Name
# diltiazem hydrochloride  16.000000  22.545455   7.727273   21.454545
# docetaxel injection      24.875000  27.000000  24.500000   20.750000
# ketamine hydrochloride    9.333333  14.800000  11.500000   23.555556
#
# Parameter
# Date                    16-10-2020 17-10-2020
# Drug_Name
# diltiazem hydrochloride  37.454545  15.636364
# docetaxel injection      51.454545  17.500000
# ketamine hydrochloride   11.500000  18.500000

# %%
#HW - explore above function with different aggregate functions

# %% [markdown]
# ### **HW - explore above function with different aggregate functions**
#
# **`NOTE:`** Used **ChatGPT** for the below data.
#
# When using the **pivot_table()** function in **Pandas**, you can specify the desired **aggregation function(s)** using the **aggfunc** parameter. Here are some commonly used **aggregate functions** with **pivot_table()**:
#
# * '**sum**': Computes the sum of values.
# * '**mean**': Calculates the mean (average) of values.
# * '**median**': Computes the median of values.
# * '**min**': Returns the minimum value.
# * '**max**': Returns the maximum value.
# * '**count**': Counts the number of non-null values.
# * '**std**': Computes the standard deviation.
# * '**var**': Calculates the variance.
# * '**prod**': Computes the product of values.
# * '**first**': Returns the first value.
# * '**last**': Returns the last value.
#
# You can specify a single aggregation function or a list of multiple aggregation functions. **Here's an example:**

# %%
import pandas as pd

# Create a DataFrame
data_example = {
    'City': ['New York', 'London', 'New York', 'London', 'London'],
    'Year': [2018, 2018, 2019, 2019, 2020],
    'Sales': [100, 200, 150, 250, 300]
}
df = pd.DataFrame(data_example)

# Create a pivot table with sum and mean aggregation
pivot = df.pivot_table(values='Sales', index='City', columns='Year', aggfunc=['sum', 'mean'])

print(pivot)
# Out:
#             sum                 mean
# Year       2018   2019   2020   2018   2019   2020
# City
# London    200.0  250.0  300.0  200.0  250.0  300.0
# New York  100.0  150.0    NaN  100.0  150.0    NaN

# %% [markdown]
# **`NOTE:`** In this example, the pivot table is created with both the sum and mean aggregations for the '**Sales**' column, grouped by '**City**' and '**Year**'.

# %% [markdown]
# # **(2) How to handle missing values**
# ***
# When working with **missing values** in **Pandas**, you have two common approaches: **dropping missing values** or **imputing (filling) missing values** with some estimated or derived values. Let's go through both methods:
#
# > **`Approach (1):` Dropping Missing Values**
#
# > **`Approach (2):` Imputing Missing Values `(i.e. Imputation)`** with either **Mean**, **Median**, **Mode**...
#
# **The functions / approaches we need to work on related to missing values in Pandas**
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
data_tidy.head(20)
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# 5          15-10-2020  11:30:00   ketamine hydrochloride       9.0
# 6          15-10-2020  12:30:00  diltiazem hydrochloride      20.0
# 7          15-10-2020  12:30:00      docetaxel injection      28.0
# 8          15-10-2020  12:30:00   ketamine hydrochloride      11.0
# 9          15-10-2020   1:30:00  diltiazem hydrochloride      12.0
# 10         15-10-2020   1:30:00      docetaxel injection       NaN
# 11         15-10-2020   1:30:00   ketamine hydrochloride       8.0
# 12         15-10-2020   2:30:00  diltiazem hydrochloride      13.0
# ...

# %% [markdown]
# When working with **missing values** in **Pandas**, there are two commonly encountered representations called **None** and **NaN**, but they have different behaviors and interpretations:
#
# > **(1) None:**
#
# * **None** is a Python object of type **"NoneType"** and is commonly used in Python for representing missing or undefined values.
# * In Pandas, **None** is treated as a regular value and not recognized as a missing value by many of Pandas' built-in functions for handling missing data.
# * When **None** is present in a Pandas DataFrame or Series, it is typically treated as a regular value rather than a missing value.
#
# > **(2) NaN** (Not a Number)**:**
#
# * **NaN** is a special floating-point value defined by the IEEE standard for representing missing or undefined numerical values.
# * In Pandas, **NaN** is recognized as a missing value and can be handled using various functions for handling missing data.
# * When **NaN** is present in a numerical column of a Pandas DataFrame or Series, the dtype of the column is automatically set to float to accommodate the presence of NaN values.
# * **NaN** values are propagated through operations and are usually considered as missing data during calculations and aggregations.

# %%
type(None)
# Out:
# NoneType

# %%
type(np.nan)
# Out:
# float

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1, np.nan, 2])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# dtype: float64

# %%
# IMPORTANT: If "NaN" and "None" is presented together, it will be treated as a "NaN"
# That is, "None" will work for both "Text" as well as "Float". But "NaN" will only work for "FLoat".

pd.Series([1, np.nan, 2, None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
# "NaN" can be presented as "Float" as well as "String". But "None" will be convereted into "NaN" in order to get stored...

pd.Series(["Aditya", None, np.nan])
# Out:
# 0    Aditya
# 1      None
# 2       NaN
# dtype: object

# %% [markdown]
# ### **`Approach (1):` Dealing with missing values**
#
# When performing **missing data** operations, **Pandas** treats **'None'** as any other value and **does not** consider it as a missing value. However, **'NaN'** is recognized as a missing value and can be handled using **Pandas**' functions like **isna()**, **dropna()**, or **fillna()**.
#
# > **(1) isna() & isnull()**
#
# * The **isna()** function is used to detect missing values in a DataFrame or Series. It returns a **boolean mask** of the same shape as the input object, where **True** represents a **missing value** (**NaN** or **None**).
# * The **isnull()** function is an alias for isna() and provides the same functionality.
#
# These functions (**isna()**, **dropna()**, and **fillna()**) provide essential tools for identifying missing values, removing them, and filling them with appropriate values. They are fundamental in **handling missing data** in **Pandas**.

# %%
data.head(10)
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5  15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6  16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7  16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8  16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9  16-10-2020      docetaxel injection     Pressure     23.0     24.0
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# ...

# %%
data.isna().head()
# Out:
#     Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0  False      False      False    False    False     True    False    False
# 1  False      False      False    False    False     True    False    False
# 2  False      False      False     True    False    False     True    False
# 3  False      False      False     True    False    False     True    False
# 4  False      False      False    False     True     True    False     True
#
#    6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  12:30:00
# 0    False    False    False    False     False     False     False
# 1    False    False    False    False     False     False     False
# 2    False     True     True    False     False     False     False
# 3    False     True     True    False     False     False     False
# 4    False    False    False    False     False     False     False

# %%
data.isnull().head()
# Out:
#     Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0  False      False      False    False    False     True    False    False
# 1  False      False      False    False    False     True    False    False
# 2  False      False      False     True    False    False     True    False
# 3  False      False      False     True    False    False     True    False
# 4  False      False      False    False     True     True    False     True
#
#    6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  11:30:00  12:30:00
# 0    False    False    False    False     False     False     False
# 1    False    False    False    False     False     False     False
# 2    False     True     True    False     False     False     False
# 3    False     True     True    False     False     False     False
# 4    False    False    False    False     False     False     False

# %%
# when we call isnull() or isna(), it performs the same internally as below...

pd.isnull
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %%
pd.isna
# Out:
# <function pandas.core.dtypes.missing.isna(obj: 'object') -> 'bool | npt.NDArray[np.bool_] | NDFrame'>

# %% [markdown]
# ### **How many missing values are there in a particular row or column ???**

# %%
# How many null values are there in each row

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
# How many null values are there in each column

data.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
# How many null value are there in each row ???

data.isna().sum(axis = 1)
# Out:
# 0     1
# 1     1
# 2     4
# 3     4
# 4     3
# 5     3
# 6     1
# 7     1
# 8     1
# 9     1
# 10    2
# 11    2
# 12    1
# 13    1
# 14    0
# 15    0
# 16    0
# 17    0
# dtype: int64

# %% [markdown]
# ### **What are the rows/columns that doesn't have even one null values ???**
#
# > **(2) dropna()**
#
# * The **dropna()** function is used to remove missing values from a DataFrame.
# * By default, it drops rows containing any missing values, but you can customize the behavior using parameters such as **axis** (to drop columns instead), **thresh** (to specify a minimum number of non-null values required to keep a row or column), and others.

# %%
# What are the rows that doesn't have even one null values ???
# That is, we will get only the non-null values as o/p...

data.dropna()
# Out:
#           Date               Drug_Name    Parameter  1:30:00  2:30:00  \
# 14  17-10-2020     docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020     docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020  ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020  ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
#HW - Explore - how to drop a row when only all the cells are null

# %% [markdown]
# ### **How to drop a row when only all the cells are null ???**
# To drop a row in **Pandas** only if all cells in that row are null or missing values, you can use the **dropna()** function with the **'how'** parameter set to **'all'**. This will ensure that only rows with all missing values are dropped.

# %%
data.dropna(how = "all")
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %% [markdown]
# **What are the columns that doesn't have even one null values ???**

# %%
data.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
# What are the columns that doesn't have even one null values ???
# That is, we will get only the non-null values as o/p...

data.dropna(axis = 1)
# Out:
#           Date                Drug_Name    Parameter  6:30:00  10:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature       22        20
# 1   15-10-2020  diltiazem hydrochloride     Pressure       14        18
# 2   15-10-2020      docetaxel injection  Temperature       18        23
# 3   15-10-2020      docetaxel injection     Pressure       23        26
# 4   15-10-2020   ketamine hydrochloride  Temperature       26        22
# 5   15-10-2020   ketamine hydrochloride     Pressure        9         9
# 6   16-10-2020  diltiazem hydrochloride  Temperature       38        40
# 7   16-10-2020  diltiazem hydrochloride     Pressure       23        24
# 8   16-10-2020      docetaxel injection  Temperature       49        56
# 9   16-10-2020      docetaxel injection     Pressure       27        28
# 10  16-10-2020   ketamine hydrochloride  Temperature       12        13
# 11  16-10-2020   ketamine hydrochloride     Pressure       15        16
# ...

# %%
#break --> imputation

# %% [markdown]
# ### **`Approach (2):` Imputing Missing Values (i.e. Imputation) with either Mean, Median, Mode...**
#
# > **(3) fillna()**
#
# * The **fillna()** function is used to fill missing values in a DataFrame or Series with a specified value or strategy.
# * You can pass a scalar value, a dictionary mapping columns to values, or use strategies like filling with the **mean**, **median**, **mode**, or **forward/backward filling**.

# %%
data.head(20)
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
data.fillna(0).head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      0.0     17.0
# 3  15-10-2020      docetaxel injection     Pressure      0.0     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      0.0
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      0.0     21.0     21.0       22     23.0     21.0     22.0        20
# 1      0.0     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      0.0     17.0       18      0.0      0.0     23.0        23
# 3     22.0      0.0     22.0       23      0.0      0.0     27.0        26
# 4      0.0     27.0      0.0       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
# What to do if I want to fill NaN value into 0 with only one particular column ???

data["3:30:00"].fillna(0)
# Out:
# 0      0.0
# 1      0.0
# 2     18.0
# 3     22.0
# 4      0.0
# 5      0.0
# 6     36.0
# 7     20.0
# 8      0.0
# 9      0.0
# 10    10.0
# 11    13.0
# 12    19.0
# 13     4.0
# 14    14.0
# 15    22.0
# 16    15.0
# 17    10.0
# Name: 3:30:00, dtype: float64

# %% [markdown]
# Filling the **'NaN'** values with **0** is **not** always the right approach.
#
# Hence, for example, what is the average value of a particular column in order to fill **'NaN'** values with the **average value** of that column.

# %%
mean_val = data["2:30:00"].mean()

# %%
mean_val
# Out:
# 18.8125

# %%
data["2:30:00"]  #this column missing value will be replaced by "18.8125" istead of "NaN"
# Out:
# 0     22.0
# 1     13.0
# 2     17.0
# 3     22.0
# 4      NaN
# 5      NaN
# 6     35.0
# 7     19.0
# 8     47.0
# 9     24.0
# 10     9.0
# 11    12.0
# 12    19.0
# 13     4.0
# 14    13.0
# 15    22.0
# 16    14.0
# 17     9.0
# Name: 2:30:00, dtype: float64

# %%
data["2:30:00"].fillna(mean_val)
# Out:
# 0     22.0000
# 1     13.0000
# 2     17.0000
# 3     22.0000
# 4     18.8125
# 5     18.8125
# 6     35.0000
# 7     19.0000
# 8     47.0000
# 9     24.0000
# 10     9.0000
# 11    12.0000
# 12    19.0000
# 13     4.0000
# 14    13.0000
# 15    22.0000
# 16    14.0000
# 17     9.0000
# Name: 2:30:00, dtype: float64

# %%
# Performing the same task in one single line as per Industry Standard

data["2:30:00"].fillna(data["2:30:00"].mean())
# Out:
# 0     22.0000
# 1     13.0000
# 2     17.0000
# 3     22.0000
# 4     18.8125
# 5     18.8125
# 6     35.0000
# 7     19.0000
# 8     47.0000
# 9     24.0000
# 10     9.0000
# 11    12.0000
# 12    19.0000
# 13     4.0000
# 14    13.0000
# 15    22.0000
# 16    14.0000
# 17     9.0000
# Name: 2:30:00, dtype: float64

# %% [markdown]
# ### **Complex Imputation (i.e. SQL - "Window Functions")**
#
# So far we had a column that had all the **drug_name** and another column that had both the **Temperature** & **Pressure** parameters/metrics. We then filled any **missing values** of the **time** columns based on **average values in that column**. In that way, both the **Temperature** & **Pressure** parameters had the **same average value** for the missing value cell.
#
# However, we want to make this better for having **average values **of the missing cells for the **respective Temperature **& **Pressure** parameters group instead of the generic average value to be filled for missing value.
#
# **Example of the data and average value we had for missing value cell and how we want it to be improved**
#
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **So how to achieve this task ???**
#
# This is similar to **"Window Functions"** in **"SQL"** that we had learnt. The only **difference** you'll notice that the **grouped parameters** such as **Temperature** & **Pressure** will **not** dislay together like **"Window Frame"** in **"SQL"** but internally it will be the same.
#
# **Example of what we want the o/p to be**
#
# ![Capture.PNG](data:image/png;base64,...)

# %%
data_tidy.head(20)
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# 5          15-10-2020  11:30:00   ketamine hydrochloride       9.0
# 6          15-10-2020  12:30:00  diltiazem hydrochloride      20.0
# 7          15-10-2020  12:30:00      docetaxel injection      28.0
# 8          15-10-2020  12:30:00   ketamine hydrochloride      11.0
# 9          15-10-2020   1:30:00  diltiazem hydrochloride      12.0
# 10         15-10-2020   1:30:00      docetaxel injection       NaN
# 11         15-10-2020   1:30:00   ketamine hydrochloride       8.0
# 12         15-10-2020   2:30:00  diltiazem hydrochloride      13.0
# ...

# %%
def temp_mean(df):

  df["Temp_avg"] = df["Temperature"].mean()    # creating a new column that has the mean value
  return df

# %%
#first step we'll do the Group By of parameters (i.e. Temeprature & Pressure)
#the create a new column that has the average value of the respective group parameters

data_tidy = data_tidy.groupby("Drug_Name").apply(temp_mean)   #ignore the warning notification
# Out:
# <ipython-input-79-526d7d10dd79>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_tidy = data_tidy.groupby("Drug_Name").apply(temp_mean)   #ignore the warning notification

# %%
data_tidy.head(20)
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# 5          15-10-2020  11:30:00   ketamine hydrochloride       9.0
# 6          15-10-2020  12:30:00  diltiazem hydrochloride      20.0
# 7          15-10-2020  12:30:00      docetaxel injection      28.0
# 8          15-10-2020  12:30:00   ketamine hydrochloride      11.0
# 9          15-10-2020   1:30:00  diltiazem hydrochloride      12.0
# 10         15-10-2020   1:30:00      docetaxel injection       NaN
# 11         15-10-2020   1:30:00   ketamine hydrochloride       8.0
# 12         15-10-2020   2:30:00  diltiazem hydrochloride      13.0
# ...

# %% [markdown]
# **`NOTE:`**
# **The only difference b/w "SQL - Window Frames" o/p and "Pandas - Windo Frames" o/p**
#
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **So how to replace the missing values of the "Temperature" parameters now ???**

# %%
# simple row-level calculation

data_tidy["Temperature"].fillna(data_tidy["Temp_avg"], inplace = True)

# %%
data_tidy.head(20)
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# 5          15-10-2020  11:30:00   ketamine hydrochloride       9.0
# 6          15-10-2020  12:30:00  diltiazem hydrochloride      20.0
# 7          15-10-2020  12:30:00      docetaxel injection      28.0
# 8          15-10-2020  12:30:00   ketamine hydrochloride      11.0
# 9          15-10-2020   1:30:00  diltiazem hydrochloride      12.0
# 10         15-10-2020   1:30:00      docetaxel injection       NaN
# 11         15-10-2020   1:30:00   ketamine hydrochloride       8.0
# 12         15-10-2020   2:30:00  diltiazem hydrochloride      13.0
# ...

# %% [markdown]
# **How to do to the same task for the "Pressure" parameter as well ???**

# %%
#HW - check this code

def pr_mean(x):
  x['Pressure_avg'] = x['Pressure'].mean()   # creating a new column that has the mean value
  return x


data_tidy=data_tidy.groupby(["Drug_Name"]).apply(pr_mean)
data_tidy['Pressure'].fillna(data_tidy["Pressure_avg"], inplace=True)
data_tidy
data_tidy.isna().sum()      # we see zero missing values now
# Out:
# <ipython-input-83-e45471dcd451>:8: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_tidy=data_tidy.groupby(["Drug_Name"]).apply(pr_mean)
# Parameter
# Date            0
# time            0
# Drug_Name       0
# Pressure        0
# Temperature     0
# Temp_avg        0
# Pressure_avg    0
# dtype: int64

# %% [markdown]
# ### **How to create bins in Pandas (i.e. SQL - "Histogram bins")**
#
# In **SQL**, a **histogram** is a way to visualize the distribution of data in a column by dividing the data into **bins** or **intervals** and counting the number of occurrences within each bin. While **SQL** databases provide built-in functions for generating histograms, **Pandas** offers similar functionality to create histograms using the **cut()** and **value_counts()** methods.
#
# **Syntax for creating bins using "cut()":**
#
# > **`pd.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False)`**
#
# * **x**: The input array or DataFrame column.
# * **bins**: The bins or intervals to use for dividing the data.
# * **right**: Whether the intervals are closed on the right side (default is **True**).
# * **labels**: Optional labels for the resulting bins.
# * **retbins**: Whether to return the bins themselves (default is **False**).
# * **precision**: The precision at which to store and display the bins (default is **3**).
# * **include_lowest**: Whether to include the lowest edge of the first bin (default is **False**).

# %%
data_tidy["Temperature"].min()
# Out:
# 8.0

# %%
data_tidy["Temperature"].max()
# Out:
# 58.0

# %%
temp_points = [5, 20, 35, 50, 60]
temp_labels = ["low", "medium", "high", "very_high"]

# %%
# How to apply this bins approach ???

data_tidy["temp_cat"] = pd.cut(data_tidy["Temperature"],
                               bins = temp_points,
                               labels = temp_labels)

# %%
data_tidy.head(20)
# Out:
# Parameter        Date      time                Drug_Name   Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride  18.000000
# 1          15-10-2020  10:30:00      docetaxel injection  26.000000
# 2          15-10-2020  10:30:00   ketamine hydrochloride   9.000000
# 3          15-10-2020  11:30:00  diltiazem hydrochloride  19.000000
# 4          15-10-2020  11:30:00      docetaxel injection  29.000000
# 5          15-10-2020  11:30:00   ketamine hydrochloride   9.000000
# 6          15-10-2020  12:30:00  diltiazem hydrochloride  20.000000
# 7          15-10-2020  12:30:00      docetaxel injection  28.000000
# 8          15-10-2020  12:30:00   ketamine hydrochloride  11.000000
# 9          15-10-2020   1:30:00  diltiazem hydrochloride  12.000000
# 10         15-10-2020   1:30:00      docetaxel injection  25.483871
# 11         15-10-2020   1:30:00   ketamine hydrochloride   8.000000
# 12         15-10-2020   2:30:00  diltiazem hydrochloride  13.000000
# ...

# %% [markdown]
# **Syntax for counting occurrences using "value_counts()":**
#
# > **`Series.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True)`**
#
# * **normalize**: Whether to return frequencies instead of counts (default is **False**).
# * **sort**: Whether to sort by values (default is **True**).
# * **ascending**: Whether to sort in ascending order (default is **False**).
# * **bins**: The bins to use for grouping the data (optional).

# %% [markdown]
# **How many rows are there which are having my "low" or "medium" category ???**

# %%
data_tidy["temp_cat"].value_counts()  #frequency of each category in my bins
# Out:
# low          50
# medium       38
# high         15
# very_high     5
# Name: temp_cat, dtype: int64

# %% [markdown]
# ### **Let's work on Categorical data (i.e. SQL - "LIKE" operator)**
#
# Working with **categorical data** in **Pandas** often involves performing operations similar to the **SQL - "LIKE" operator**. Two useful methods for this purpose are **str.contains()** and **str.split()**
#
# **`(1)`str.contains() method:**
# The **str.contains()** method in **Pandas** is used to check if a pattern or substring is present in each element of a Series.
#
# **Syntax:**
# > **`Series.str.contains(pat, case=True, regex=True, na=False)`**
#
# * **pat**: The pattern or substring to search for.
# * **case**: Whether to perform a case-sensitive search (default is **True**).
# * **regex**: Whether to treat the pattern as a regular expression (default is **True**).
# * **na**: Whether to consider missing values as False (default is **False**).

# %% [markdown]
# **Give me only those rows where the drug_name contains "hydrochloride"**

# %%
data_tidy.loc[data_tidy["Drug_Name"].str.contains("hydrochloride")] #string operation similar to "like" in sql
# Out:
# Parameter        Date      time                Drug_Name   Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride  18.000000
# 2          15-10-2020  10:30:00   ketamine hydrochloride   9.000000
# 3          15-10-2020  11:30:00  diltiazem hydrochloride  19.000000
# 5          15-10-2020  11:30:00   ketamine hydrochloride   9.000000
# 6          15-10-2020  12:30:00  diltiazem hydrochloride  20.000000
# ..                ...       ...                      ...        ...
# 101        17-10-2020   7:30:00   ketamine hydrochloride  12.000000
# 102        17-10-2020   8:30:00  diltiazem hydrochloride  15.424242
# 104        17-10-2020   8:30:00   ketamine hydrochloride  11.000000
# 105        17-10-2020   9:30:00  diltiazem hydrochloride   9.000000
# 107        17-10-2020   9:30:00   ketamine hydrochloride  12.000000
#
# Parameter  Temperature   Temp_avg  Pressure_avg temp_cat
# 0            20.000000  24.848485     15.424242      low
# ...

# %%
data_tidy["Date"]
# Out:
# 0      15-10-2020
# 1      15-10-2020
# 2      15-10-2020
# 3      15-10-2020
# 4      15-10-2020
#           ...
# 103    17-10-2020
# 104    17-10-2020
# 105    17-10-2020
# 106    17-10-2020
# 107    17-10-2020
# Name: Date, Length: 108, dtype: object

# %% [markdown]
# **`(2)` str.split() method:**
# The **str.split()** method in Pandas is used to split strings in each element of a Series into substrings based on a specified delimiter.
#
# **Syntax:**
# > **`Series.str.split(pat=None, n=-1, expand=False)`**
#
# * **pat**: The delimiter to use for splitting (default is whitespace).
# * **n**: The maximum number of splits (default is -1, which means all occurrences).
# * **expand**: Whether to expand the split strings into separate columns (default is **False**).

# %%
data_tidy["Date"].str.split("-")
# Out:
# 0      [15, 10, 2020]
# 1      [15, 10, 2020]
# 2      [15, 10, 2020]
# 3      [15, 10, 2020]
# 4      [15, 10, 2020]
#             ...
# 103    [17, 10, 2020]
# 104    [17, 10, 2020]
# 105    [17, 10, 2020]
# 106    [17, 10, 2020]
# 107    [17, 10, 2020]
# Name: Date, Length: 108, dtype: object

# %% [markdown]
# ### **Let's try to create timestamp now**

# %%
data_tidy.head()
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
#
# Parameter  Temperature   Temp_avg  Pressure_avg temp_cat
# 0                 20.0  24.848485     15.424242      low
# 1                 23.0  30.387097     25.483871   medium
# 2                 22.0  17.709677     11.935484   medium
# 3                 20.0  24.848485     15.424242      low
# 4                 25.0  30.387097     25.483871   medium

# %%
data_tidy["timestamp"] = data_tidy["Date"] + " " + data_tidy["time"]  #NOTE: you can use "pd.concat()" as well but this is simpler...

# %%
data_tidy.head()
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
#
# Parameter  Temperature   Temp_avg  Pressure_avg temp_cat            timestamp
# 0                 20.0  24.848485     15.424242      low  15-10-2020 10:30:00
# 1                 23.0  30.387097     25.483871   medium  15-10-2020 10:30:00
# 2                 22.0  17.709677     11.935484   medium  15-10-2020 10:30:00
# 3                 20.0  24.848485     15.424242      low  15-10-2020 11:30:00
# 4                 25.0  30.387097     25.483871   medium  15-10-2020 11:30:00

# %%
# What's the datatype of timestamp ???

data_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 0 to 107
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          108 non-null    object
#  1   time          108 non-null    object
#  2   Drug_Name     108 non-null    object
#  3   Pressure      108 non-null    float64
#  4   Temperature   108 non-null    float64
#  5   Temp_avg      108 non-null    float64
#  6   Pressure_avg  108 non-null    float64
#  7   temp_cat      108 non-null    category
#  8   timestamp     108 non-null    object
# dtypes: category(1), float64(4), object(4)
# memory usage: 12.0+ KB

# %% [markdown]
# ### **Let's work on datetime functions simiar to "SQL"**

# %%
data_tidy["timestamp"] = pd.to_datetime(data_tidy["timestamp"])

# %%
data_tidy.info()   #the datatype of timestamp has been changed correctly...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 0 to 107
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          108 non-null    object
#  1   time          108 non-null    object
#  2   Drug_Name     108 non-null    object
#  3   Pressure      108 non-null    float64
#  4   Temperature   108 non-null    float64
#  5   Temp_avg      108 non-null    float64
#  6   Pressure_avg  108 non-null    float64
#  7   temp_cat      108 non-null    category
#  8   timestamp     108 non-null    datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(4), object(3)
# memory usage: 12.0+ KB

# %% [markdown]
# **Let's pick up one value and apply all the functions in that**

# %%
data_tidy.head()
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
#
# Parameter  Temperature   Temp_avg  Pressure_avg temp_cat           timestamp
# 0                 20.0  24.848485     15.424242      low 2020-10-15 10:30:00
# 1                 23.0  30.387097     25.483871   medium 2020-10-15 10:30:00
# 2                 22.0  17.709677     11.935484   medium 2020-10-15 10:30:00
# 3                 20.0  24.848485     15.424242      low 2020-10-15 11:30:00
# 4                 25.0  30.387097     25.483871   medium 2020-10-15 11:30:00

# %%
ts = data_tidy["timestamp"][0]   #first value of that column

# %%
print(ts)
# Out:
# 2020-10-15 10:30:00

# %% [markdown]
# ### **Let's see very simple functions that will help us to obtain data (i.e. "SQL - EXTRACT function")**
#
# Remember, we will be able to handle the below codes only because the column **"timestamp"** has **"datetime" object** as the **data type**...
#
# **Pandas** provides several other useful **datetime**-related **functions** and **attributes**. Here are some commonly used ones:
#
# > **Date Components:**
#
# * **year**: Extracts the year from a datetime-like object.
# * **.month**: Extracts the month from a datetime-like object (1 to 12).
# * **.day**: Extracts the day of the month from a datetime-like object (1 to 31).
# * **.dayofweek**: Extracts the day of the week from a datetime-like object (Monday=0, Sunday=6).
# * **.day_name()**: Returns the name of the day of the week.
# * **.quarter**: Extracts the quarter from a datetime-like object.
# * **.month_name()**: Returns the name of the month.
# * **.isocalendar()**: Returns a tuple of ISO year, ISO week number, and ISO weekday.
# * **.days_in_month**: Returns the number of days in the month of the datetime-like object.
#
# > **Time Components:**
#
# * **.hour**: Extracts the hour from a datetime-like object (0 to 23).
# * **.minute**: Extracts the minute from a datetime-like object (0 to 59).
# * **.second**: Extracts the second from a datetime-like object (0 to 59).
# * **.microsecond**: Extracts the microsecond from a datetime-like object.
# * **.strftime()**: Formats a datetime-like object into a string using a specified format code. (e.g., .**strftime('%S')**, **.strftime('%M')**, **.strftime('%H')**)
#
# > **Date Arithmetic:**
#
# * **.date()**: Extracts the date part (year, month, day) from a datetime-like object.
# * **.time()**: Extracts the time part (hour, minute, second, microsecond) from a datetime-like object.
# * **.timedelta()**: Performs arithmetic operations with datetime-like objects to calculate time differences.
# * **.to_period()**: Converts a datetime-like object to a specific period or frequency.

# %%
ts.year
# Out:
# 2020

# %%
ts.month
# Out:
# 10

# %%
ts.day
# Out:
# 15

# %%
ts.month_name()
# Out:
# 'October'

# %%
ts.hour
# Out:
# 10

# %%
ts.minute
# Out:
# 30

# %%
print(ts.strftime('%S')) #not frequently used
# Out:
# 00

# %%
print(ts.strftime('%M')) #not frequently used
# Out:
# 30

# %%
data_tidy.head()
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
#
# Parameter  Temperature   Temp_avg  Pressure_avg temp_cat           timestamp
# 0                 20.0  24.848485     15.424242      low 2020-10-15 10:30:00
# 1                 23.0  30.387097     25.483871   medium 2020-10-15 10:30:00
# 2                 22.0  17.709677     11.935484   medium 2020-10-15 10:30:00
# 3                 20.0  24.848485     15.424242      low 2020-10-15 11:30:00
# 4                 25.0  30.387097     25.483871   medium 2020-10-15 11:30:00

# %% [markdown]
# # **How to store all of my Analysis and share it to other ???**
# ***

# %%
data_tidy.to_csv("pandas4_work.csv", sep= ",")
